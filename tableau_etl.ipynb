# %%
# Import Dependencies
import pandas as pd 

# read csv as df
df_01 = pd.read_csv("Resources/JC-202001-citibike-tripdata.csv")
df_02 = pd.read_csv("Resources/JC-202002-citibike-tripdata.csv")
df_03 = pd.read_csv("Resources/JC-202003-citibike-tripdata.csv")
df_04 = pd.read_csv("Resources/JC-202004-citibike-tripdata.csv")
df_05 = pd.read_csv("Resources/JC-202005-citibike-tripdata.csv")
df_06 = pd.read_csv("Resources/JC-202006-citibike-tripdata.csv")
df_07 = pd.read_csv("Resources/JC-202007-citibike-tripdata.csv")
df_08 = pd.read_csv("Resources/JC-202008-citibike-tripdata.csv")
df_09 = pd.read_csv("Resources/JC-202009-citibike-tripdata.csv")
df_10 = pd.read_csv("Resources/JC-202010-citibike-tripdata.csv")
df_11 = pd.read_csv("Resources/JC-202011-citibike-tripdata.csv")
df_12 = pd.read_csv("Resources/JC-202012-citibike-tripdata.csv")

# %%
df_01.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           226  2020-01-01 00:04:50.1920  2020-01-01 00:08:37.0370
# 1           377  2020-01-01 00:16:01.6700  2020-01-01 00:22:19.0800
# 2           288  2020-01-01 00:17:33.8770  2020-01-01 00:22:22.4420
# 3           435  2020-01-01 00:32:05.9020  2020-01-01 00:39:21.0660
# 4           231  2020-01-01 00:46:19.6780  2020-01-01 00:50:11.3440
#
#    start station id start station name  start station latitude  \
# 0              3186      Grove St PATH               40.719586
# 1              3186      Grove St PATH               40.719586
# 2              3186      Grove St PATH               40.719586
# 3              3195            Sip Ave               40.730897
# 4              3186      Grove St PATH               40.719586
#
#    start station longitude  end station id  end station name  \
# 0               -74.043117            3211        Newark Ave
# ...

# %%
df_02.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           841  2020-02-01 00:02:13.7650  2020-02-01 00:16:15.4720
# 1           206  2020-02-01 00:16:11.3850  2020-02-01 00:19:37.4460
# 2           859  2020-02-01 00:23:22.1090  2020-02-01 00:37:41.5060
# 3           693  2020-02-01 00:25:14.5170  2020-02-01 00:36:48.0280
# 4          1473  2020-02-01 00:32:30.5050  2020-02-01 00:57:04.3740
#
#    start station id  start station name  start station latitude  \
# 0              3199        Newport Pkwy               40.728745
# 1              3273        Manila & 1st               40.721651
# 2              3185           City Hall               40.717732
# 3              3185           City Hall               40.717732
# 4              3192  Liberty Light Rail               40.711242
#
#    start station longitude  end station id         end station name  \
# 0               -74.032108            3213           Van Vorst Park
# ...

# %%
df_01.columns
# Out:
# Index(['tripduration', 'starttime', 'stoptime', 'start station id',
#        'start station name', 'start station latitude',
#        'start station longitude', 'end station id', 'end station name',
#        'end station latitude', 'end station longitude', 'bikeid', 'usertype',
#        'birth year', 'gender'],
#       dtype='object')

# %%
df_01.shape
# (26020, 15)
# Out:
# (26020, 15)

# %%
df_01.describe()
# Out:
#         tripduration  start station id  start station latitude  \
# count   26020.000000      26020.000000            26020.000000
# mean      540.897540       3305.578094               40.722574
# std      4249.238936        184.011111                0.006669
# min        61.000000       3184.000000               40.711130
# 25%       225.000000       3195.000000               40.718355
# 50%       326.000000       3211.000000               40.721525
# 75%       501.000000       3276.000000               40.726012
# max    520598.000000       3792.000000               40.748716
#
#        start station longitude  end station id  end station latitude  \
# count             26020.000000    26020.000000          26020.000000
# mean                -74.046602     3305.218217             40.722256
# std                   0.010983      186.618387              0.006521
# min                 -74.083639      525.000000             40.709651
# ...

# %%
df_01.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26020 entries, 0 to 26019
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   tripduration             26020 non-null  int64
#  1   starttime                26020 non-null  object
#  2   stoptime                 26020 non-null  object
#  3   start station id         26020 non-null  int64
#  4   start station name       26020 non-null  object
#  5   start station latitude   26020 non-null  float64
#  6   start station longitude  26020 non-null  float64
#  7   end station id           26020 non-null  int64
#  8   end station name         26020 non-null  object
#  9   end station latitude     26020 non-null  float64
#  10  end station longitude    26020 non-null  float64
#  11  bikeid                   26020 non-null  int64
#  12  usertype                 26020 non-null  object
#  13  birth year               26020 non-null  int64
# ...

# %%
# combine datasets
bike_df = pd.merge(df_01, df_02, how="outer")
bike_df.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           226  2020-01-01 00:04:50.1920  2020-01-01 00:08:37.0370
# 1           377  2020-01-01 00:16:01.6700  2020-01-01 00:22:19.0800
# 2           288  2020-01-01 00:17:33.8770  2020-01-01 00:22:22.4420
# 3           435  2020-01-01 00:32:05.9020  2020-01-01 00:39:21.0660
# 4           231  2020-01-01 00:46:19.6780  2020-01-01 00:50:11.3440
#
#    start station id start station name  start station latitude  \
# 0              3186      Grove St PATH               40.719586
# 1              3186      Grove St PATH               40.719586
# 2              3186      Grove St PATH               40.719586
# 3              3195            Sip Ave               40.730897
# 4              3186      Grove St PATH               40.719586
#
#    start station longitude  end station id  end station name  \
# 0               -74.043117            3211        Newark Ave
# ...

# %%
bike_df.tail()
# Out:
#        tripduration                 starttime                  stoptime  \
# 48977           262  2020-02-29 23:40:53.1620  2020-02-29 23:45:15.3180
# 48978           216  2020-02-29 23:41:01.3350  2020-02-29 23:44:38.0350
# 48979           101  2020-02-29 23:45:22.1700  2020-02-29 23:47:03.2970
# 48980           279  2020-02-29 23:47:56.8380  2020-02-29 23:52:36.6400
# 48981           212  2020-02-29 23:49:18.4510  2020-02-29 23:52:50.7490
#
#        start station id start station name  start station latitude  \
# 48977              3639         Harborside               40.719252
# 48978              3186      Grove St PATH               40.719586
# 48979              3214   Essex Light Rail               40.712774
# 48980              3186      Grove St PATH               40.719586
# 48981              3184        Paulus Hook               40.714145
#
#        start station longitude  end station id  end station name  \
# ...

# %%
bike_df.shape
# (48982, 15)
# Out:
# (48982, 15)

# %%
bike_df = pd.merge(bike_df, df_03, how="outer")
bike_df.shape
# (66701, 15)
# Out:
# (66701, 15)

# %%
bike_df = pd.merge(bike_df, df_04, how="outer")
bike_df.shape
# (75969, 15)
# Out:
# (75969, 15)

# %%
bike_df = pd.merge(bike_df, df_05, how="outer")
bike_df.shape
# (101046, 15)
# Out:
# (101046, 15)

# %%
bike_df = pd.merge(bike_df, df_06, how="outer")
bike_df.shape
# (137967, 15)
# Out:
# (137967, 15)

# %%
bike_df = pd.merge(bike_df, df_07, how="outer")
bike_df.shape
# (176647, 15)
# Out:
# (176647, 15)

# %%
bike_df = pd.merge(bike_df, df_08, how="outer")
bike_df.shape
# (219914, 15)
# Out:
# (219914, 15)

# %%
bike_df = pd.merge(bike_df, df_09, how="outer")
bike_df.shape
# (273747, 15)
# Out:
# (273747, 15)

# %%
bike_df = pd.merge(bike_df, df_10, how="outer")
bike_df.shape
# (290382, 15)
# Out:
# (290382, 15)

# %%
bike_df = pd.merge(bike_df, df_11, how="outer")
bike_df.shape
# (311657, 15)
# Out:
# (311657, 15)

# %%
bike_df = pd.merge(bike_df, df_12, how="outer")
bike_df.shape
# (323351, 15)
# Out:
# (323351, 15)

# %%
bike_df.head()
# Out:
#    tripduration                 starttime                  stoptime  \
# 0           226  2020-01-01 00:04:50.1920  2020-01-01 00:08:37.0370
# 1           377  2020-01-01 00:16:01.6700  2020-01-01 00:22:19.0800
# 2           288  2020-01-01 00:17:33.8770  2020-01-01 00:22:22.4420
# 3           435  2020-01-01 00:32:05.9020  2020-01-01 00:39:21.0660
# 4           231  2020-01-01 00:46:19.6780  2020-01-01 00:50:11.3440
#
#    start station id start station name  start station latitude  \
# 0              3186      Grove St PATH               40.719586
# 1              3186      Grove St PATH               40.719586
# 2              3186      Grove St PATH               40.719586
# 3              3195            Sip Ave               40.730897
# 4              3186      Grove St PATH               40.719586
#
#    start station longitude  end station id  end station name  \
# 0               -74.043117            3211        Newark Ave
# ...

# %%
bike_df.tail()
# Out:
#         tripduration                 starttime                  stoptime  \
# 323346          1750  2020-12-31 23:07:44.0030  2020-12-31 23:36:54.4710
# 323347          1519  2020-12-31 23:18:00.2630  2020-12-31 23:43:19.8590
# 323348          1761  2020-12-31 23:31:09.4620  2021-01-01 00:00:31.3290
# 323349           637  2020-12-31 23:35:45.4640  2020-12-31 23:46:22.7300
# 323350          1607  2020-12-31 23:48:34.5750  2021-01-01 00:15:22.3090
#
#         start station id start station name  start station latitude  \
# 323346              3199       Newport Pkwy               40.728745
# 323347              3184        Paulus Hook               40.714145
# 323348              3195            Sip Ave               40.730897
# 323349              3681           Grand St               40.715178
# 323350              3267       Morris Canal               40.712419
#
#         start station longitude  end station id end station name  \
# ...

# %%
bike_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 323351 entries, 0 to 323350
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   tripduration             323351 non-null  int64
#  1   starttime                323351 non-null  object
#  2   stoptime                 323351 non-null  object
#  3   start station id         323351 non-null  int64
#  4   start station name       323351 non-null  object
#  5   start station latitude   323351 non-null  float64
#  6   start station longitude  323351 non-null  float64
#  7   end station id           323351 non-null  int64
#  8   end station name         323351 non-null  object
#  9   end station latitude     323351 non-null  float64
#  10  end station longitude    323351 non-null  float64
#  11  bikeid                   323351 non-null  int64
#  12  usertype                 323351 non-null  object
# ...

# %%
bike_df.columns
# Out:
# Index(['tripduration', 'starttime', 'stoptime', 'start station id',
#        'start station name', 'start station latitude',
#        'start station longitude', 'end station id', 'end station name',
#        'end station latitude', 'end station longitude', 'bikeid', 'usertype',
#        'birth year', 'gender'],
#       dtype='object')

# %%
bike_df.describe()
# Out:
#        tripduration  start station id  start station latitude  \
# count  3.233510e+05      323351.00000           323351.000000
# mean   1.591808e+03        3304.22663               40.722223
# std    1.836775e+04         184.68836                0.007355
# min    6.100000e+01        3184.00000               40.709651
# 25%    3.260000e+02        3195.00000               40.716870
# 50%    6.150000e+02        3209.00000               40.721124
# 75%    1.426000e+03        3276.00000               40.727224
# max    3.261756e+06        3792.00000               40.748716
#
#        start station longitude  end station id  end station latitude  \
# count            323351.000000   323351.000000         323351.000000
# mean                -74.046770     3302.821191             40.721730
# std                   0.011914      190.244243              0.101542
# min                 -74.083639       82.000000              0.000000
# ...

# %%
bike_df.to_csv("Resources/bike_full_2020.csv")
